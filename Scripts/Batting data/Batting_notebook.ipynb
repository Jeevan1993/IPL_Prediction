# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import numpy as np
import json
from espncricinfo.match import Match
from espncricinfo.player import Player
import pandas as pd
dataset=pd.DataFrame()
 #IPL_2008-2019_match_ids.npy
m=np.load('/home/g1/Documents/Cricket/Batting data/IPL_2008-2019_match_ids.npy')
count_main=0

# %%
for match_no in m[50:]:#[1:2]: 
    count_main+=1
    print("Bat Match ID=",count_main)
    print("Match no",match_no)
#    mm = Match(m[-1])
    mm = Match(match_no)
    #p = Player('940973')
    ##    
    pp=np.zeros([2,11])
    for i in range(2):
        for j in range(11):
            pp[i,j]=mm.json['team'][i]['player'][j]['object_id']
            c=mm.json['team'][i]['player'][j]['object_id']
    
    pba=np.zeros([2,11])
    pbs=np.zeros([2,11])              
    for i in range(2):
        print(" Team:",i)
        for j in range(11):
#            print("Team:",i)#,"player:",j)
            p = Player(int(pp[i,j]))
            count=0
            count1=0
            count2=0
            a=0;b=0;c=0;d=0;e=0;f=0;sum1=0;sum2=0
            #if dictionary contains t20 then get from t20, else 5
            if ('T20Is' in p.batting_fielding_averages.keys()):
                a=p.batting_fielding_averages['T20Is']['batting_average']
                if a==''or a=='-': a='0'
                #if a.replace('.','').isdigit():
                a=a.replace('*','')
                if a!='0':
                    count1+=1
                b=p.batting_fielding_averages['T20Is']['strike_rate']
                if b=='' or b=='-': b='0'
                b=b.replace('*','')
                if b!='0':
                #if b.replace('.','').isdigit():
                    count2+=1
                count+=1
                
#            print("1")
            if ('T20s' in p.batting_fielding_averages.keys()):
                c=p.batting_fielding_averages['T20s']['batting_average']
                if c=='' or c=='-': c='0'
                c=c.replace('*','')
                #if c.replace('.','').isdigit():
                if c!='0':
                    count1+=1
                d=p.batting_fielding_averages['T20s']['strike_rate']
                if d==''or d=='-': d='0'
                d=d.replace('*','')
                if d!='0':
                #if d.replace('.','').isdigit():
                    count2+=1
                count+=1
                
#            print("2")
                
            if count1==2:
                sum1=(float(a)+float(c))/count1
            else:
                if ('List A' in p.batting_fielding_averages.keys()):
                    e=p.batting_fielding_averages['List A']['batting_average']
                    if e==''or e=='-': e='0'
                    e=e.replace('*','')
                    #if e.replace('.','').isdigit():
                    if e!='0':
                        count1+=1
                        sum1=(float(a)+float(c)+float(e)/2)/count1
                        
                    elif count1!=0:
                        sum1=(float(a)+float(c))/count1
                        
#            print("3")
                
            if count2==2:    
                sum2=(float(b)+float(d))/count2
            else:
                if ('List A' in p.batting_fielding_averages.keys()):
                    f=p.batting_fielding_averages['List A']['strike_rate']
                    if f=='' or f=='-': f='0'
                    f=f.replace('*','')
                    if f!='0':
                    #if f.replace('.','').isdigit():
                        count2+=1
                        sum2=(float(b)+float(d)+float(f)*1.5)/count2
                        
                    elif count2!=0:
                        sum2=(float(b)+float(d))/count2
                       
#            print("4")
                        
#            print("i=",i,"j=",j, "Passed")
            pba[i,j]=sum1
            pbs[i,j]=sum2
#            print("Avg=",pba[i,j],"strrate=",pbs[i,j],"econ",pbe[i,j])
                
    
    x=np.hstack(pba)
    y=np.hstack(pbs)
    xy=[np.hstack([x,y])]
    dataset=dataset.append(xy)
dataset.to_csv(r'bat.csv',index=False)
print("Done Getting data. Saved as CSV")
# Out:
# Bat Match ID= 1
# Match no 336035
#  Team: 0
#  Team: 1
# Bat Match ID= 2
# Match no 336036
#  Team: 0
#  Team: 1
# Bat Match ID= 3
# Match no 336037
#  Team: 0
#  Team: 1
# Bat Match ID= 4
# Match no 336012
#  Team: 0
#  Team: 1
# Bat Match ID= 5
# Match no 336019
#  Team: 0
#  Team: 1
# Bat Match ID= 6
# Match no 336038
#  Team: 0
#  Team: 1
# Bat Match ID= 7
# Match no 336039
#  Team: 0
#  Team: 1
# Bat Match ID= 8
# Match no 336040
#  Team: 0
#  Team: 1
# Bat Match ID= 9
# Match no 392181
#  Team: 0
#  Team: 1
# Bat Match ID= 10
# Match no 392182
#  Team: 0
#  Team: 1
# Bat Match ID= 11
# Match no 392183
#  Team: 0
#  Team: 1
# Bat Match ID= 12
# Match no 392184
#  Team: 0
#  Team: 1
# Bat Match ID= 13
# Match no 392185
#  Team: 0
#  Team: 1
# Bat Match ID= 14
# Match no 392186
#  Team: 0
#  Team: 1
# Bat Match ID= 15
# Match no 392188
#  Team: 0
#  Team: 1
# Bat Match ID= 16
# Match no 392189
#  Team: 0
#  Team: 1
# Bat Match ID= 17
# Match no 392190
#  Team: 0
#  Team: 1
# Bat Match ID= 18
# Match no 392191
#  Team: 0
#  Team: 1
# Bat Match ID= 19
# Match no 392192
#  Team: 0
#  Team: 1
# Bat Match ID= 20
# Match no 392194
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-a3db60f1f5ab> in <module>
#       5     print("Match no",match_no)
#       6 #    mm = Match(m[-1])
# ----> 7     mm = Match(match_no)
#       8     #p = Player('940973')
#       9     ##
#
# ~/anaconda3/lib/python3.7/site-packages/espncricinfo/match.py in __init__(self, match_id)
#      56             self.team_1_abbreviation = self._team_1_abbreviation()
#      57             self.team_1_players = self._team_1_players()
# ---> 58             self.team_1_innings = self._team_1_innings()
#      59             self.team_1_run_rate = self._team_1_run_rate()
#      60             self.team_1_overs_batted = self._team_1_overs_batted()
#
# ~/anaconda3/lib/python3.7/site-packages/espncricinfo/match.py in _team_1_innings(self)
#     276
#     277     def _team_1_innings(self):
# --> 278         return [inn for inn in self.json['innings'] if inn['batting_team_id'] == self._team_1_id()][0]
#     279
#     280     def _team_1_run_rate(self):
#
# IndexError: list index out of range
